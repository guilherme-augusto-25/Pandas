# %%
#pandas
import pandas as pd

tabela = pd.read_excel(r"C:\Users\User\Desktop\Base Vendas.xlsx")
display(tabela)
# Out:
#          SKU     Produto  Quantidade Vendida Primeiro Nome   Sobrenome  \
# 0     HL4379   Televisão                   5       Gabriel       Thoni
# 1     HL4379   Televisão                   3         Renan  Nascimento
# 2     HL1148      Câmera                   2        Camila      Sobral
# 3     HL1918      iPhone                   3         Clara       Bruno
# 4     HL9962     Android                   4       Eduardo     Pacheco
# ...      ...         ...                 ...           ...         ...
# 9994  HL4379   Televisão                   2          Caio    Ferreira
# 9995  HL1148      Câmera                   5           Kim    Ferreira
# 9996  HL4379   Televisão                   5          Caio      Moraes
# 9997  HL1918      iPhone                   4        Norman       Jimbo
# 9998  HL7348  SmartWatch                   1      Vinícius     Antunes
#
#             Data          Loja  Preco Unitario
# 0      6/30/2018      Curitiba            2500
# ...

# %%
tabela =pd.read_excel(r"C:\Users\User\Desktop\Base Vendas.xlsx",
                  header=0,
                  names=['col1','col2','col3']
                 )
tabela.head()
# Out:
#                                              col1       col2  col3
# HL4379 Televisão 5 Gabriel Thoni        6/30/2018   Curitiba  2500
#                  3 Renan   Nascimento   9/14/2018     Recife  2500
# HL1148 Câmera    2 Camila  Sobral      10/21/2018  Fortaleza  2100
# HL1918 iPhone    3 Clara   Bruno         7/8/2018  Fortaleza  5300
# HL9962 Android   4 Eduardo Pacheco     12/19/2018  Fortaleza  3400

# %%
tabela.rename(columns={'col1': 'Data_Hora'}, inplace=True)
tabela.head()
# Out:
#                                         Data_Hora       col2  col3
# HL4379 Televisão 5 Gabriel Thoni        6/30/2018   Curitiba  2500
#                  3 Renan   Nascimento   9/14/2018     Recife  2500
# HL1148 Câmera    2 Camila  Sobral      10/21/2018  Fortaleza  2100
# HL1918 iPhone    3 Clara   Bruno         7/8/2018  Fortaleza  5300
# HL9962 Android   4 Eduardo Pacheco     12/19/2018  Fortaleza  3400

# %%
tabela.rename(columns={'col2': 'Vara'}, inplace=True)
tabela.head()
# Out:
#                                         Data_Hora       Vara  col3
# HL4379 Televisão 5 Gabriel Thoni        6/30/2018   Curitiba  2500
#                  3 Renan   Nascimento   9/14/2018     Recife  2500
# HL1148 Câmera    2 Camila  Sobral      10/21/2018  Fortaleza  2100
# HL1918 iPhone    3 Clara   Bruno         7/8/2018  Fortaleza  5300
# HL9962 Android   4 Eduardo Pacheco     12/19/2018  Fortaleza  3400

# %%
tabela.rename(columns={'col3': 'teste'}, inplace=True)
tabela.head()
# Out:
#                                         Data_Hora       Vara  teste
# HL4379 Televisão 5 Gabriel Thoni        6/30/2018   Curitiba   2500
#                  3 Renan   Nascimento   9/14/2018     Recife   2500
# HL1148 Câmera    2 Camila  Sobral      10/21/2018  Fortaleza   2100
# HL1918 iPhone    3 Clara   Bruno         7/8/2018  Fortaleza   5300
# HL9962 Android   4 Eduardo Pacheco     12/19/2018  Fortaleza   3400

# %%
tabela['col4'] = 0
tabela.head()
# Out:
#                                         Data_Hora       Vara  teste  col4
# HL4379 Televisão 5 Gabriel Thoni        6/30/2018   Curitiba   2500     0
#                  3 Renan   Nascimento   9/14/2018     Recife   2500     0
# HL1148 Câmera    2 Camila  Sobral      10/21/2018  Fortaleza   2100     0
# HL1918 iPhone    3 Clara   Bruno         7/8/2018  Fortaleza   5300     0
# HL9962 Android   4 Eduardo Pacheco     12/19/2018  Fortaleza   3400     0
